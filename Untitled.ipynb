# %% [markdown]
# # Célula 1 — Introdução e Objetivo
#
# Estudo de Caso com Dados Reais (Petrópolis)
#
# Este notebook demonstra a aplicação do pipeline completo para um lote real da cidade de Petrópolis,
# utilizando geometria georreferenciada e otimizando a forma edificada com heurísticas e agentes autônomos.
#
# Fluxo:
# 1. Carregamento do lote e faces
# 2. Validação e parametrização
# 3. Geração e otimização da morfologia
# 4. Exportação e visualização do resultado final
#
#
# Instalação das bibliotecas necessárias (se ainda não instaladas)
#
# !pip install geopandas shapely h3

# %%
import sys
import os

# Adiciona a raiz do projeto ao PYTHONPATH
sys.path.append(os.path.abspath("."))  # ou "../" se estiver rodando de uma subpasta

from pipelines.modeling_pipeline import run_modeling_pipeline
from core.model import BuildingModel
from dataio.exporter import BuildingExporter
import geopandas as gpd
import matplotlib.pyplot as plt

# %% [markdown]
# # Célula 2 — Caminhos dos dados reais

# %%
# Caminho dos dados reais (adaptar conforme sua estrutura de pastas)
lot_path = "./data/petropolis_bairro_lotes_com_faces_unidos_parametros_simular.geojson"
face_path = "./data/petropolis_bairro_lotes_lados_lotes_detalhados.geojson"
output_path = "./output_petropolis"

# %%
lotes = gpd.read_file(lot_path)
lotes.columns
# Out:
# Index(['numlote', 'lados_frente', 'lados_laterais', 'lados_fundos',
#        'id_quarteirao', 'faces_frente', 'comprimento_frente',
#        'num_faces_frente', 'faces_lateral', 'comprimento_lateral',
#        'num_faces_lateral', 'faces_fundo', 'comprimento_fundo',
#        'num_faces_fundo', 'comprimento_total', 'proporcao_frente_fundo',
#        'pct_frente', 'pct_lateral', 'pct_fundo', 'index_right', 'codigo',
#        'nome', 'zot', 'obs', 'ga', 'conceito', 'min_far', 'max_far',
#        'max_height', 'height_border', 'back_setback_percent',
#        'permeability_rate', 'max_lot_coverage', 'min_front_setback',
#        'gf_height', 'uf_height', 'min_floor_ratio', 'min_back_setback',
#        'min_side_setback', 'min_setback_start_floor', 'shape_ratio',
#        'geometry'],
#       dtype='object')

# %%
lotes[['codigo','nome', 'zot',]]
# Out:
#     codigo        nome    zot
# 0      149  PETRÓPOLIS  ZOT 7
# 1      149  PETRÓPOLIS  ZOT 7
# 2      149  PETRÓPOLIS  ZOT 7
# 3      149  PETRÓPOLIS  ZOT 7
# 4      149  PETRÓPOLIS  ZOT 7
# 5      149  PETRÓPOLIS  ZOT 7
# 6      149  PETRÓPOLIS  ZOT 7
# 7      149  PETRÓPOLIS  ZOT 7
# 8      149  PETRÓPOLIS  ZOT 7
# 9      149  PETRÓPOLIS  ZOT 7
# 10     149  PETRÓPOLIS  ZOT 7
# 11     149  PETRÓPOLIS  ZOT 7
# 12     149  PETRÓPOLIS  ZOT 7
# 13     149  PETRÓPOLIS  ZOT 7
# 14     149  PETRÓPOLIS  ZOT 7
# 15     149  PETRÓPOLIS  ZOT 7
# 16     149  PETRÓPOLIS  ZOT 7
# 17     149  PETRÓPOLIS  ZOT 7
# 18     149  PETRÓPOLIS  ZOT 7
# 19     149  PETRÓPOLIS  ZOT 7
# 20     149  PETRÓPOLIS  ZOT 7
# 21     149  PETRÓPOLIS  ZOT 7
# 22     149  PETRÓPOLIS  ZOT 7
# 23     149  PETRÓPOLIS  ZOT 7
# 24     149  PETRÓPOLIS  ZOT 7
# 25     149  PETRÓPOLIS  ZOT 7
# 26     149  PETRÓPOLIS  ZOT 7
# 27     149  PETRÓPOLIS  ZOT 7
# 28     149  PETRÓPOLIS  ZOT 7
# 29     149  PETRÓPOLIS  ZOT 7
# 30     149  PETRÓPOLIS  ZOT 7
# 31     149  PETRÓPOLIS  ZOT 7
# 32     149  PETRÓPOLIS  ZOT 7
# 33     149  PETRÓPOLIS  ZOT 7
# 34     149  PETRÓPOLIS  ZOT 7
# 35     149  PETRÓPOLIS  ZOT 7
# 36     149  PETRÓPOLIS  ZOT 7
# 37     149  PETRÓPOLIS  ZOT 7
# 38     149  PETRÓPOLIS  ZOT 7
# 39     149  PETRÓPOLIS  ZOT 7
# 40     149  PETRÓPOLIS  ZOT 7
# 41     149  PETRÓPOLIS  ZOT 7
# 42     149  PETRÓPOLIS  ZOT 7
# 43     149  PETRÓPOLIS  ZOT 7
# 44     149  PETRÓPOLIS  ZOT 7
# 45     149  PETRÓPOLIS  ZOT 7
# 46     149  PETRÓPOLIS  ZOT 7
# 47     149  PETRÓPOLIS  ZOT 7
# 48     149  PETRÓPOLIS  ZOT 7

# %% [markdown]
# # Célula  — Execução do pipeline

# %%
results = run_modeling_pipeline(
    lot_path=lot_path,
    face_path=face_path,
    output_path=output_path,
    model_prefix="petropolis"
)
# Out:
# [Erro ao gerar footprint]: Unrecognized type: <class 'dict'>
# [!] Modelo petropolis_001720590000 não possui footprint válido.
# [Erro ao gerar footprint]: Unrecognized type: <class 'dict'>
# [!] Modelo petropolis_000448560000 não possui footprint válido.
# [Erro ao gerar footprint]: Unrecognized type: <class 'dict'>
# [!] Modelo petropolis_001312670000 não possui footprint válido.
# [Erro ao gerar footprint]: Unrecognized type: <class 'dict'>
# [!] Modelo petropolis_001064600000 não possui footprint válido.
# [Erro ao gerar footprint]: Unrecognized type: <class 'dict'>
# [!] Modelo petropolis_001068910000 não possui footprint válido.
# [Erro ao gerar footprint]: Unrecognized type: <class 'dict'>
# [!] Modelo petropolis_001720540000 não possui footprint válido.
# [Erro ao gerar footprint]: Unrecognized type: <class 'dict'>
# [!] Modelo petropolis_001723370000 não possui footprint válido.
# [Erro ao gerar footprint]: Unrecognized type: <class 'dict'>
# [!] Modelo petropolis_000204210000 não possui footprint válido.
# [Erro ao gerar footprint]: Unrecognized type: <class 'dict'>
# [!] Modelo petropolis_001723940000 não possui footprint válido.
# [Erro ao gerar footprint]: Unrecognized type: <class 'dict'>
# [!] Modelo petropolis_001008620000 não possui footprint válido.
# [Erro ao gerar footprint]: Unrecognized type: <class 'dict'>
# [!] Modelo petropolis_002647650000 não possui footprint válido.
# [Erro ao gerar footprint]: Unrecognized type: <class 'dict'>
# [!] Modelo petropolis_000443020000 não possui footprint válido.
# [Erro ao gerar footprint]: Unrecognized type: <class 'dict'>
# [!] Modelo petropolis_001622320000 não possui footprint válido.
# [Erro ao gerar footprint]: Unrecognized type: <class 'dict'>
# [!] Modelo petropolis_001513600000 não possui footprint válido.
# [Erro ao gerar footprint]: Unrecognized type: <class 'dict'>
# [!] Modelo petropolis_000697140000 não possui footprint válido.
# [Erro ao gerar footprint]: Unrecognized type: <class 'dict'>
# [!] Modelo petropolis_001032730000 não possui footprint válido.
# [Erro ao gerar footprint]: Unrecognized type: <class 'dict'>
# [!] Modelo petropolis_001820840000 não possui footprint válido.
# [Erro ao gerar footprint]: Unrecognized type: <class 'dict'>
# [!] Modelo petropolis_001089990000 não possui footprint válido.
# [Erro ao gerar footprint]: Unrecognized type: <class 'dict'>
# [!] Modelo petropolis_001633970000 não possui footprint válido.
# [Erro ao gerar footprint]: Unrecognized type: <class 'dict'>
# [!] Modelo petropolis_002069730000 não possui footprint válido.
# [Erro ao gerar footprint]: Unrecognized type: <class 'dict'>
# [!] Modelo petropolis_001622500000 não possui footprint válido.
# [Erro ao gerar footprint]: Unrecognized type: <class 'dict'>
# [!] Modelo petropolis_001395260000 não possui footprint válido.
# [Erro ao gerar footprint]: Unrecognized type: <class 'dict'>
# [!] Modelo petropolis_000490150000 não possui footprint válido.
# [Erro ao gerar footprint]: Unrecognized type: <class 'dict'>
# [!] Modelo petropolis_000549560000 não possui footprint válido.
# [Erro ao gerar footprint]: Unrecognized type: <class 'dict'>
# [!] Modelo petropolis_001197680000 não possui footprint válido.
# [Erro ao gerar footprint]: Unrecognized type: <class 'dict'>
# [!] Modelo petropolis_001012160000 não possui footprint válido.
# [Erro ao gerar footprint]: Unrecognized type: <class 'dict'>
# [!] Modelo petropolis_001724230000 não possui footprint válido.
# [Erro ao gerar footprint]: Unrecognized type: <class 'dict'>
# [!] Modelo petropolis_001724400000 não possui footprint válido.
# [Erro ao gerar footprint]: Unrecognized type: <class 'dict'>
# [!] Modelo petropolis_001129190000 não possui footprint válido.
# [Erro ao gerar footprint]: Unrecognized type: <class 'dict'>
# [!] Modelo petropolis_001102020000 não possui footprint válido.
# [Erro ao gerar footprint]: Unrecognized type: <class 'dict'>
# [!] Modelo petropolis_001746110000 não possui footprint válido.
# [Erro ao gerar footprint]: Unrecognized type: <class 'dict'>
# [!] Modelo petropolis_001494980000 não possui footprint válido.
# [Erro ao gerar footprint]: Unrecognized type: <class 'dict'>
# [!] Modelo petropolis_001344220000 não possui footprint válido.
# [Erro ao gerar footprint]: Unrecognized type: <class 'dict'>
# [!] Modelo petropolis_001750110000 não possui footprint válido.
# [Erro ao gerar footprint]: Unrecognized type: <class 'dict'>
# [!] Modelo petropolis_001411340000 não possui footprint válido.
# [Erro ao gerar footprint]: Unrecognized type: <class 'dict'>
# [!] Modelo petropolis_001723770000 não possui footprint válido.
# [Erro ao gerar footprint]: Unrecognized type: <class 'dict'>
# [!] Modelo petropolis_001724670000 não possui footprint válido.
# [Erro ao gerar footprint]: Unrecognized type: <class 'dict'>
# [!] Modelo petropolis_001724710000 não possui footprint válido.
# [Erro ao gerar footprint]: Unrecognized type: <class 'dict'>
# [!] Modelo petropolis_002365090000 não possui footprint válido.
# [Erro ao gerar footprint]: Unrecognized type: <class 'dict'>
# [!] Modelo petropolis_001057150000 não possui footprint válido.
# [Erro ao gerar footprint]: Unrecognized type: <class 'dict'>
# [!] Modelo petropolis_001977860000 não possui footprint válido.
# [Erro ao gerar footprint]: Unrecognized type: <class 'dict'>
# [!] Modelo petropolis_001965760000 não possui footprint válido.
# [Erro ao gerar footprint]: Unrecognized type: <class 'dict'>
# [!] Modelo petropolis_001030270000 não possui footprint válido.
# [Erro ao gerar footprint]: Unrecognized type: <class 'dict'>
# [!] Modelo petropolis_001858200000 não possui footprint válido.
# [Erro ao gerar footprint]: Unrecognized type: <class 'dict'>
# [!] Modelo petropolis_000037030000 não possui footprint válido.
# [Erro ao gerar footprint]: Unrecognized type: <class 'dict'>
# [!] Modelo petropolis_001257270000 não possui footprint válido.
# [Erro ao gerar footprint]: Unrecognized type: <class 'dict'>
# [!] Modelo petropolis_001259440000 não possui footprint válido.
# [Erro ao gerar footprint]: Unrecognized type: <class 'dict'>
# [!] Modelo petropolis_001312520000 não possui footprint válido.
# [Erro ao gerar footprint]: Unrecognized type: <class 'dict'>
# [!] Modelo petropolis_001259420000 não possui footprint válido.

# %% [markdown]
# # Célula 5 — Visualização do resultado

# %%
# Escolha um ID real que tenha sido processado com sucesso (ex: "3303906_010203")
model_file = "./output_petropolis/petropolis_3303906_010203.geojson"

gdf = gpd.read_file(model_file)
gdf.plot(edgecolor='black', facecolor='lightblue', figsize=(8, 8))
plt.title("Edificação Gerada - Petrópolis")
plt.axis('equal')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# File fiona\\ogrext.pyx:136, in fiona.ogrext.gdal_open_vector()
#
# File fiona\\_err.pyx:291, in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: ./output_petropolis/petropolis_3303906_010203.geojson: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# Cell In[8], line 4
#       1 # Escolha um ID real que tenha sido processado com sucesso (ex: "3303906_010203")
#       2 model_file = "./output_petropolis/petropolis_3303906_010203.geojson"
# ----> 4 gdf = gpd.read_file(model_file)
#       5 gdf.plot(edgecolor='black', facecolor='lightblue', figsize=(8, 8))
#       6 plt.title("Edificação Gerada - Petrópolis")
#
# File ~\anaconda3\Lib\site-packages\geopandas\io\file.py:289, in _read_file(filename, bbox, mask, rows, engine, **kwargs)
#     286     else:
#     287         path_or_bytes = filename
# --> 289     return _read_file_fiona(
#     290         path_or_bytes, from_bytes, bbox=bbox, mask=mask, rows=rows, **kwargs
#     291     )
#     293 else:
#     294     raise ValueError(f"unknown engine '{engine}'")
#
# File ~\anaconda3\Lib\site-packages\geopandas\io\file.py:315, in _read_file_fiona(path_or_bytes, from_bytes, bbox, mask, rows, where, **kwargs)
#     312     reader = fiona.open
#     314 with fiona_env():
# --> 315     with reader(path_or_bytes, **kwargs) as features:
#     316         crs = features.crs_wkt
#     317         # attempt to get EPSG code
#
# File ~\anaconda3\Lib\site-packages\fiona\env.py:457, in ensure_env_with_credentials.<locals>.wrapper(*args, **kwds)
#     454     session = DummySession()
#     456 with env_ctor(session=session):
# --> 457     return f(*args, **kwds)
#
# File ~\anaconda3\Lib\site-packages\fiona\__init__.py:305, in open(fp, mode, driver, schema, crs, encoding, layer, vfs, enabled_drivers, crs_wkt, allow_unsupported_drivers, **kwargs)
#     302     path = parse_path(fp)
#     304 if mode in ("a", "r"):
# --> 305     colxn = Collection(
#     306         path,
#     307         mode,
#     308         driver=driver,
#     309         encoding=encoding,
#     310         layer=layer,
#     311         enabled_drivers=enabled_drivers,
#     312         allow_unsupported_drivers=allow_unsupported_drivers,
#     313         **kwargs
#     314     )
#     315 elif mode == "w":
#     316     colxn = Collection(
#     317         path,
#     318         mode,
#    (...)
#     327         **kwargs
#     328     )
#
# File ~\anaconda3\Lib\site-packages\fiona\collection.py:243, in Collection.__init__(self, path, mode, driver, schema, crs, encoding, layer, vsi, archive, enabled_drivers, crs_wkt, ignore_fields, ignore_geometry, include_fields, wkt_version, allow_unsupported_drivers, **kwargs)
#     241 if self.mode == "r":
#     242     self.session = Session()
# --> 243     self.session.start(self, **kwargs)
#     244 elif self.mode in ("a", "w"):
#     245     self.session = WritingSession()
#
# File fiona\\ogrext.pyx:588, in fiona.ogrext.Session.start()
#
# File fiona\\ogrext.pyx:143, in fiona.ogrext.gdal_open_vector()
#
# DriverError: ./output_petropolis/petropolis_3303906_010203.geojson: No such file or directory

# %% [markdown]
# # Célula 6 — Análise final do estudo de caso

# %%
area_gerada = gdf.geometry.area.sum()
print(f"Área total construída gerada: {area_gerada:.2f} m²")
